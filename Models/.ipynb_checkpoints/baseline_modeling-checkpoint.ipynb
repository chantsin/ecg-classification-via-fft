# %% [markdown]
# ## Baseline Modeling
#
# In this notebook, we will go over a few baseline models to test out our data. Instead of using the whole data set, we will only be working with a sample of it using a function in our `functions.py` file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import wfdb
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import functions as f

# %% [markdown]
# Let's load a sample of our data set and feed it into a simple neural network.

# %%
path = '../data/physionet.org/files/ptb-xl/1.0.3/'
metadata = pd.read_csv('../data/cleaned_metadata.csv')

# Load sample data using high frequency
X_sample, y_sample = f.load_sample_signal(5000, path, metadata, freq='high')

# %% [markdown]
# Below we have the option of reshaping our data if we wish to by flattening the 12 leads out. Otherwise we set Lead 2 as the signal we look at for all ECG signals.

# %%
# Reshaping 
# X_sample = X_sample.reshape(100, -1)
X_sample = X_sample[:,:,1]
X_sample.shape
# Out:
# (5000, 5000)

# %% [markdown]
# We also need to change our labels in our target column to numerical values. We can do that using `LabelEncoder()`.

# %%
label = LabelEncoder()
label.fit(y_sample)
y_sample = label.transform(y_sample)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_sample, y_sample, test_size=0.2, stratify=y_sample, random_state=42)

# %%
# Example signal
sig_len = X_sample.shape[1]
sampling_frequency = 500

time = np.arange(0, sig_len) / sampling_frequency

plt.figure(figsize=(15,5))
plt.plot(time, X_sample[0,:])
plt.title("Sample Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude (mV)")
plt.show()

# %% [markdown]
# ### Logistic Regression
#
# Let's use the same train and test data on a Logistic Regression model. We will split our data into bins based on amplitude and try to classify from there.

# %%
# Binning with the sample signal above
plt.hist(X_train[0,:], bins=np.linspace(-0.5, 1, 20))
plt.title("Amplitude binning of sample signal")
plt.show()

# %%
counts, bins = np.histogram(X_train[0,:], bins=np.linspace(-0.5, 1, 20))
counts
# Out:
# array([   0,    0,    0,   20,  680, 2051, 1834,   91,   31,   32,   24,
#          28,   13,   26,   23,   21,   37,   43,   42])

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Instantiate model
logreg = LogisticRegression(max_iter=500)

# Fit model
logreg.fit(X_train, y_train)

# Score
print(f"Training score: {logreg.score(X_train, y_train)}")
print(f"Testing score: {logreg.score(X_test, y_test)}")
# Out:
# Training score: 0.742
# Testing score: 0.293

# %% [markdown]
# As we can see with the scoring Logistic Regression does not do well with our data. This is expected as the signals we are dealing with have a lot of noise. This is also why we need to use Fourier Transforms for our signal before we do modelling.

# %% [markdown]
# ### Simple Neural Network Classifier
# Let's build a simple neural network classifier to test out how it behaves.

# %%
# Neural Network 
model = Sequential()

# Hidden layers
model.add(layers.Dense(sig_len, activation='relu'))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(500, activation='relu'))
model.add(layers.Dropout(0.7))
model.add(layers.Dense(25, activation='relu'))

# Output layers
model.add(layers.Dense(5, activation='softmax'))

# %%
model.compile(
    # Optimizer
    optimizer=Adam(learning_rate=0.0005),  # learning rate can be adjusted here
    # Loss function to minimize
    loss=SparseCategoricalCrossentropy(),
    # Metric used to evaluate model
    metrics=[SparseCategoricalAccuracy()]
)

# %%
history = model.fit(X_train, y_train, epochs=30, verbose=2, validation_split=0.1,
                    #callbacks=[keras.callbacks.EarlyStopping()]
                   )
# Out:
# Epoch 1/30
# 113/113 - 9s - loss: 1.6340 - sparse_categorical_accuracy: 0.3711 - val_loss: 1.5019 - val_sparse_categorical_accuracy: 0.4500 - 9s/epoch - 76ms/step
# Epoch 2/30
# 113/113 - 8s - loss: 1.5229 - sparse_categorical_accuracy: 0.4142 - val_loss: 1.5097 - val_sparse_categorical_accuracy: 0.4500 - 8s/epoch - 67ms/step
# Epoch 3/30
# 113/113 - 7s - loss: 1.4950 - sparse_categorical_accuracy: 0.4272 - val_loss: 1.4897 - val_sparse_categorical_accuracy: 0.4500 - 7s/epoch - 66ms/step
# Epoch 4/30
# 113/113 - 7s - loss: 1.4642 - sparse_categorical_accuracy: 0.4306 - val_loss: 1.4879 - val_sparse_categorical_accuracy: 0.4300 - 7s/epoch - 65ms/step
# Epoch 5/30
# 113/113 - 7s - loss: 1.4297 - sparse_categorical_accuracy: 0.4417 - val_loss: 1.4903 - val_sparse_categorical_accuracy: 0.3925 - 7s/epoch - 66ms/step
# Epoch 6/30
# 113/113 - 7s - loss: 1.3725 - sparse_categorical_accuracy: 0.4494 - val_loss: 1.5028 - val_sparse_categorical_accuracy: 0.4400 - 7s/epoch - 66ms/step
# Epoch 7/30
# 113/113 - 8s - loss: 1.3487 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.4693 - val_sparse_categorical_accuracy: 0.4350 - 8s/epoch - 67ms/step
# Epoch 8/30
# 113/113 - 8s - loss: 1.3309 - sparse_categorical_accuracy: 0.4600 - val_loss: 1.5176 - val_sparse_categorical_accuracy: 0.4300 - 8s/epoch - 68ms/step
# Epoch 9/30
# 113/113 - 8s - loss: 1.2778 - sparse_categorical_accuracy: 0.4783 - val_loss: 1.4776 - val_sparse_categorical_accuracy: 0.4050 - 8s/epoch - 68ms/step
# Epoch 10/30
# 113/113 - 8s - loss: 1.2670 - sparse_categorical_accuracy: 0.4819 - val_loss: 1.5013 - val_sparse_categorical_accuracy: 0.4150 - 8s/epoch - 68ms/step
# Epoch 11/30
# 113/113 - 8s - loss: 1.2213 - sparse_categorical_accuracy: 0.5003 - val_loss: 1.5445 - val_sparse_categorical_accuracy: 0.3875 - 8s/epoch - 73ms/step
# Epoch 12/30
# 113/113 - 8s - loss: 1.2012 - sparse_categorical_accuracy: 0.5000 - val_loss: 1.5321 - val_sparse_categorical_accuracy: 0.3875 - 8s/epoch - 70ms/step
# Epoch 13/30
# 113/113 - 8s - loss: 1.1464 - sparse_categorical_accuracy: 0.5242 - val_loss: 1.5720 - val_sparse_categorical_accuracy: 0.3875 - 8s/epoch - 71ms/step
# Epoch 14/30
# 113/113 - 8s - loss: 1.1327 - sparse_categorical_accuracy: 0.5283 - val_loss: 1.6650 - val_sparse_categorical_accuracy: 0.3750 - 8s/epoch - 69ms/step
# Epoch 15/30
# 113/113 - 8s - loss: 1.1104 - sparse_categorical_accuracy: 0.5433 - val_loss: 1.6337 - val_sparse_categorical_accuracy: 0.4175 - 8s/epoch - 69ms/step
# Epoch 16/30
# 113/113 - 8s - loss: 1.0780 - sparse_categorical_accuracy: 0.5539 - val_loss: 1.6682 - val_sparse_categorical_accuracy: 0.3200 - 8s/epoch - 69ms/step
# Epoch 17/30
# 113/113 - 8s - loss: 1.0588 - sparse_categorical_accuracy: 0.5625 - val_loss: 1.6787 - val_sparse_categorical_accuracy: 0.3850 - 8s/epoch - 68ms/step
# Epoch 18/30
# 113/113 - 8s - loss: 1.0423 - sparse_categorical_accuracy: 0.5814 - val_loss: 1.6236 - val_sparse_categorical_accuracy: 0.3675 - 8s/epoch - 68ms/step
# Epoch 19/30
# 113/113 - 8s - loss: 0.9767 - sparse_categorical_accuracy: 0.5989 - val_loss: 1.7996 - val_sparse_categorical_accuracy: 0.3975 - 8s/epoch - 68ms/step
# Epoch 20/30
# 113/113 - 8s - loss: 0.9701 - sparse_categorical_accuracy: 0.6111 - val_loss: 1.8309 - val_sparse_categorical_accuracy: 0.3550 - 8s/epoch - 69ms/step
# Epoch 21/30
# 113/113 - 8s - loss: 0.9445 - sparse_categorical_accuracy: 0.6242 - val_loss: 1.7639 - val_sparse_categorical_accuracy: 0.3700 - 8s/epoch - 69ms/step
# Epoch 22/30
# 113/113 - 8s - loss: 0.9285 - sparse_categorical_accuracy: 0.6303 - val_loss: 1.8490 - val_sparse_categorical_accuracy: 0.3575 - 8s/epoch - 69ms/step
# Epoch 23/30
# 113/113 - 8s - loss: 0.8966 - sparse_categorical_accuracy: 0.6486 - val_loss: 1.8799 - val_sparse_categorical_accuracy: 0.3725 - 8s/epoch - 69ms/step
# Epoch 24/30
# 113/113 - 8s - loss: 0.8919 - sparse_categorical_accuracy: 0.6597 - val_loss: 1.9683 - val_sparse_categorical_accuracy: 0.3800 - 8s/epoch - 69ms/step
# Epoch 25/30
# 113/113 - 8s - loss: 0.8470 - sparse_categorical_accuracy: 0.6739 - val_loss: 1.9557 - val_sparse_categorical_accuracy: 0.3725 - 8s/epoch - 68ms/step
# Epoch 26/30
# 113/113 - 8s - loss: 0.8309 - sparse_categorical_accuracy: 0.6850 - val_loss: 2.1185 - val_sparse_categorical_accuracy: 0.3675 - 8s/epoch - 69ms/step
# Epoch 27/30
# 113/113 - 8s - loss: 0.7676 - sparse_categorical_accuracy: 0.7014 - val_loss: 2.0867 - val_sparse_categorical_accuracy: 0.3325 - 8s/epoch - 68ms/step
# Epoch 28/30
# 113/113 - 8s - loss: 0.7478 - sparse_categorical_accuracy: 0.7089 - val_loss: 2.2469 - val_sparse_categorical_accuracy: 0.3300 - 8s/epoch - 68ms/step
# Epoch 29/30
# 113/113 - 8s - loss: 0.7289 - sparse_categorical_accuracy: 0.7258 - val_loss: 2.1574 - val_sparse_categorical_accuracy: 0.3500 - 8s/epoch - 69ms/step
# Epoch 30/30
# 113/113 - 8s - loss: 0.6973 - sparse_categorical_accuracy: 0.7392 - val_loss: 2.2484 - val_sparse_categorical_accuracy: 0.3675 - 8s/epoch - 68ms/step

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 5000)              25005000
#
#  dropout_2 (Dropout)         (None, 5000)              0
#
#  dense_5 (Dense)             (None, 500)               2500500
#
#  dropout_3 (Dropout)         (None, 500)               0
#
#  dense_6 (Dense)             (None, 25)                12525
#
#  dense_7 (Dense)             (None, 5)                 130
#
# =================================================================
# Total params: 27,518,155
# Trainable params: 27,518,155
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Evaluate the model using the test data and generate predictions
train_accuracy = history.history["sparse_categorical_accuracy"][-1]
result = model.evaluate(X_test, y_test, verbose=0)

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {result[1]:.4f}")
# Out:
# Train Accuracy: 0.7392
# Test Accuracy: 0.3430

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'])
plt.show()
